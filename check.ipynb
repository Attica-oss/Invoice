# %%
from dataframe.netlist import netList

# %%
netList.collect()
# Out:
# C:\Users\gmounac\AppData\Local\Temp\ipykernel_9948\228486554.py:1: UserWarning: Sortedness of columns cannot be checked when 'by' groups provided
#   netList.collect()
# shape: (4_537, 11)
# ┌────────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬────────┬───────────┐
# │ date       ┆ vessel     ┆ start_tim ┆ destinati ┆ … ┆ total_ton ┆ service   ┆ Price  ┆ invoice_v │
# │ ---        ┆ ---        ┆ e         ┆ on        ┆   ┆ nage      ┆ ---       ┆ ---    ┆ alue      │
# │ date       ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ str       ┆ f64    ┆ ---       │
# │            ┆            ┆ time      ┆ str       ┆   ┆ f64       ┆           ┆        ┆ f64       │
# ╞════════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪════════╪═══════════╡
# │ 2025-01-03 ┆ ALAKRANA   ┆ 13:33:00  ┆ MSFU00027 ┆ … ┆ 9.49      ┆ Full OSS  ┆ 0.0    ┆ 0.0       │
# ...

# %%
from data_source.make_dataset import load_gsheet_data
from data_source.sheet_ids import OPS_SHEET_ID

net_list_sheet = "UnloadingSummary"


load_gsheet_data(OPS_SHEET_ID, net_list_sheet).collect().columns
# Out:
# ['Date',
#  'Vessel',
#  'startTime',
#  'Container (Destination)',
#  'overtime',
#  'Storage',
#  'endTime',
#  'Total Tonnage',
#  'Operation Type']
